# %%
from pycaret.regression import *
from pandas_profiling import ProfileReport

# %%
from pycaret.datasets import get_data
data = get_data('insurance')
data.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
prof = ProfileReport(data)
prof
# Out:
# ...
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;&lt;meta name=author content=&quot;Simon Brugman and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v2.8.0&quot;&gt;&lt;meta name=url content=https://github.com/pandas-profiling/pandas-profiling&gt;&lt;meta name=date content=&quot;2020-09-22 14:49:20.352260&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
s2=setup(data ,target='charges', session_id = 123, normalize = True, polynomial_features = True, trigonometry_features = True, feature_interaction=True, 
      bin_numeric_features= ['age', 'bmi'])
# Out:
#
# Setup Succesfully Completed.
# <style  type="text/css" >
#     #T_eec3db40_fce3_11ea_a358_54271e242e1arow15_col1 {
#             background-color:  yellow;
#         }    #T_eec3db40_fce3_11ea_a358_54271e242e1arow25_col1 {
#             background-color:  yellow;
#         }    #T_eec3db40_fce3_11ea_a358_54271e242e1arow32_col1 {
#             background-color:  yellow;
#         }    #T_eec3db40_fce3_11ea_a358_54271e242e1arow34_col1 {
#             background-color:  yellow;
#         }    #T_eec3db40_fce3_11ea_a358_54271e242e1arow39_col1 {
#             background-color:  yellow;
#         }</style><table id="T_eec3db40_fce3_11ea_a358_54271e242e1a" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
# ...

# %%
# return best model
best = compare_models()
# Out:
# <style  type="text/css" >
#     #T_6dbb6d8a_fce4_11ea_b4dc_54271e242e1a th {
#           text-align: left;
#     }    #T_6dbb6d8a_fce4_11ea_b4dc_54271e242e1arow0_col0 {
#             text-align:  left;
#         }    #T_6dbb6d8a_fce4_11ea_b4dc_54271e242e1arow0_col1 {
#             : ;
#             text-align:  left;
#         }    #T_6dbb6d8a_fce4_11ea_b4dc_54271e242e1arow0_col2 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_6dbb6d8a_fce4_11ea_b4dc_54271e242e1arow0_col3 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_6dbb6d8a_fce4_11ea_b4dc_54271e242e1arow0_col4 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_6dbb6d8a_fce4_11ea_b4dc_54271e242e1arow0_col5 {
#             : ;
#             text-align:  left;
#         }    #T_6dbb6d8a_fce4_11ea_b4dc_54271e242e1arow0_col6 {
#             : ;
#             text-align:  left;
# ...

# %%
models()
# Out:
#                                        Name  \
# ID
# lr                        Linear Regression
# lasso                      Lasso Regression
# ridge                      Ridge Regression
# en                              Elastic Net
# lar                  Least Angle Regression
# llar           Lasso Least Angle Regression
# omp             Orthogonal Matching Pursuit
# br                           Bayesian Ridge
# ard       Automatic Relevance Determination
# par            Passive Aggressive Regressor
# ransac              Random Sample Consensus
# tr                       TheilSen Regressor
# huber                       Huber Regressor
# kr                             Kernel Ridge
# svm                  Support Vector Machine
# knn                   K Neighbors Regressor
# dt                            Decision Tree
# rf                            Random Forest
# et                    Extra Trees Regressor
# ada                      AdaBoost Regressor
# ...

# %%
et = create_model('xgboost')
# Out:
# <style  type="text/css" >
#     #T_f9adaf8c_fce4_11ea_ae6d_54271e242e1arow10_col0 {
#             background:  yellow;
#         }    #T_f9adaf8c_fce4_11ea_ae6d_54271e242e1arow10_col1 {
#             background:  yellow;
#         }    #T_f9adaf8c_fce4_11ea_ae6d_54271e242e1arow10_col2 {
#             background:  yellow;
#         }    #T_f9adaf8c_fce4_11ea_ae6d_54271e242e1arow10_col3 {
#             background:  yellow;
#         }    #T_f9adaf8c_fce4_11ea_ae6d_54271e242e1arow10_col4 {
#             background:  yellow;
#         }    #T_f9adaf8c_fce4_11ea_ae6d_54271e242e1arow10_col5 {
#             background:  yellow;
# ...

# %%
plot_model(et)

# %%
save_model(et, 'deployment1_22092020')
# Out:
# Transformation Pipeline and Model Succesfully Saved

# %%
# how to load the model in pycharm
deployment_28042020 = load_model('deployment1_13092020')
# Out:
# Transformation Pipeline and Model Successfully Loaded

# %%
deployment_28042020
# Out:
# Pipeline(memory=None,
#          steps=[('dtypes',
#                  DataTypes_Auto_infer(categorical_features=[],
#                                       display_types=True, features_todrop=[],
#                                       ml_usecase='regression',
#                                       numerical_features=[], target='charges',
#                                       time_features=[])),
#                 ('imputer',
#                  Simple_Imputer(categorical_strategy='not_available',
#                                 numeric_strategy='mean',
#                                 target_variable=None)),
#                 ('new_levels1',
#                  New_Catagorical_Levels...
#                  ExtraTreesRegressor(bootstrap=False, ccp_alpha=0.0,
#                                      criterion='mse', max_depth=None,
#                                      max_features='auto', max_leaf_nodes=None,
#                                      max_samples=None,
# ...
