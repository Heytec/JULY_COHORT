# %% [markdown]
# # What is pandas (Python data analysis library)

# %% [markdown]
# pandas is a fast, powerful, flexible and easy to use open source data analysis and manipulation tool,
# built on top of the Python programming language.

# %% [markdown]
# ## Pandas is well suited for many different kinds of data:
#
# * Tabular data with heterogeneously-typed columns, as in an SQL table or Excel spreadsheet
# * Ordered and unordered (not necessarily fixed-frequency) time series data.
# * Arbitrary matrix data with row and column labels
# * Any other form of observational / statistical data sets.

# %% [markdown]
# # Getting started¶

# %% [markdown]
# ## Installation
#
# ### Working with conda?
#    conda install pandas
#
# ### Prefer pip?
#    pip install pandas

# %%
# To load the pandas package and start working with it, import the package. 
import pandas as pd

#check  the version of pandas 
print(pd.__version__)
# Out:
# 1.0.1

# %% [markdown]
# # What kind of data does Pandas handle?

# %% [markdown]
# When working with tabular data, such as data stored in spreadsheets or databases, Pandas is the right tool for you. Pandas will help you to explore, clean and process your data. In Pandas, a data table is called a DataFrame.

# %% [markdown]
# ![dataframe](img/pandas_data_structure.png)

# %%
# how  to create a dataframe 
students={"Name": ["Braund, Mr. Owen Harris",
            "Allen, Mr. William Henry",
         "Bonnell, Miss. Elizabeth"],
  "Marks": [22, 35, 58],
  "Sex": ["male", "male", "female"]}
    

df = pd.DataFrame(data=students)
df
# Out:
#                        Name  Marks     Sex
# 0   Braund, Mr. Owen Harris     22    male
# 1  Allen, Mr. William Henry     35    male
# 2  Bonnell, Miss. Elizabeth     58  female

# %%
# Each column in a DataFrame is a Series¶
df["Marks"]
# Out:
# 0    22
# 1    35
# 2    58
# Name: Marks, dtype: int64

# %%
#You can create a Series from scratch as well:
marks = pd.Series([22, 35, 58], name="Age")
marks
# Out:
# 0    22
# 1    35
# 2    58
# Name: Age, dtype: int64

# %% [markdown]
# Do something with a DataFrame or Series
# * View the first 2 columns
# * view the last 3 columns
# * I want to know the maximum Marks  of the Students ?
# * I’m interested in some basic statistics of the numerical data of my data tabled ?
# * datatypes ?

# %%
#View the first 2 columns 
df.head(2)
# Out:
#                        Name  Marks   Sex
# 0   Braund, Mr. Owen Harris     22  male
# 1  Allen, Mr. William Henry     35  male

# %%
#view the last 3 columns 
df.tail(3)
# Out:
#                        Name  Marks     Sex
# 0   Braund, Mr. Owen Harris     22    male
# 1  Allen, Mr. William Henry     35    male
# 2  Bonnell, Miss. Elizabeth     58  female

# %% [markdown]
# I want to know the maximum Marks  of the Students ?

# %%
df["Marks"].max()
# Out:
# 58

# %% [markdown]
#  I’m interested in some basic statistics of the numerical data of my data table ?

# %%
df.describe()
# Out:
#            Marks
# count   3.000000
# mean   38.333333
# std    18.230012
# min    22.000000
# 25%    28.500000
# 50%    35.000000
# 75%    46.500000
# max    58.000000

# %% [markdown]
# #datatypes ?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    3 non-null      object
#  1   Marks   3 non-null      int64
#  2   Sex     3 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 200.0+ bytes

# %% [markdown]
# # How do I read and write tabular data?

# %% [markdown]
# Pandas supports the integration with many file formats or data sources out of the box (csv, excel, sql, json, parquet,…). Importing data from each of these data sources is provided by function with the prefix read_*. Similarly, the to_* methods are used to store data.

# %% [markdown]
# ![title](img/panda_data.png)

# %% [markdown]
#  I want to analyse the telcom churn data , available as a CSV file.

# %%
telcom=pd.read_csv('Telco_Churn.csv')

# %%
#Make sure to always have a check on the data after reading in the data.
#When displaying a DataFrame, the first and last 5 rows will be shown by default:
telcom
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %% [markdown]
#  My colleague requested the telcom data as a spreadsheet.

# %%
#
telcom.to_excel('telcom.xlsx', sheet_name='customers', index=False)

# %% [markdown]
# The equivalent read function to_excel() will reload the data to a DataFrame ?

# %%
#The equivalent read function to_excel() will reload the data to a DataFrame:
telcom_excel= pd.read_excel('telcom.xlsx', sheet_name='customers')
telcom_excel.head(1)
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-month              Yes
#
#       PaymentMethod MonthlyCharges  TotalCharges Churn
# 0  Electronic check          29.85         29.85    No
#
# [1 rows x 21 columns]

# %% [markdown]
# i’m interested in a technical summary of a DataFrame

# %%
#I’m interested in a technical summary of a DataFrame
telcom_excel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %% [markdown]
# #A check on how pandas interpreted each of the column data types ?

# %%
#A check on how pandas interpreted each of the column data types 
telcom.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %% [markdown]
# # How do I select a subset of a table?
# Selecting or filtering specific rows and/or columns? Filtering the data on a condition? Methods for slicing, selecting, and extracting the data you need are available in Pandas.

# %% [markdown]
# ![title](img/subset.png)

# %% [markdown]
# #I’m interested in MonthlyCharges of the telcom customers?

# %%
#I’m interested in MonthlyCharges of the telcom customers.

#To select a single column, use square brackets [] with the column name of the column of interest.
MonthlyCharges=telcom['MonthlyCharges']
# view first 5
MonthlyCharges.head()
# Out:
# 0    29.85
# 1    56.95
# 2    53.85
# 3    42.30
# 4    70.70
# Name: MonthlyCharges, dtype: float64

# %%
#And have a look at the shape of the output:
type(telcom['MonthlyCharges'])
telcom['MonthlyCharges'].shape
# Out:
# (7043,)

# %% [markdown]
# I’m interested in the MonthlyCharges and Totalcharges  of the telcom customers .

# %%
#To select multiple columns, use a list of column names within the selection brackets [].
revenue = telcom[["MonthlyCharges", "TotalCharges","Churn"] ]
revenue.head()
# Out:
#    MonthlyCharges TotalCharges Churn
# 0           29.85        29.85    No
# 1           56.95       1889.5    No
# 2           53.85       108.15   Yes
# 3           42.30      1840.75    No
# 4           70.70       151.65   Yes

# %% [markdown]
# I’m interested in the customers  who paid  more than 100 in MonthlyCharges    .

# %%
paid_above_100 = telcom[ telcom["MonthlyCharges"] >100 ]
paid_above_100.head()
# Out:
#     customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 8   7892-POOKP  Female              0     Yes         No      28          Yes
# 12  8091-TTVAX    Male              0     Yes         No      58          Yes
# 13  0280-XJGEX    Male              0      No         No      49          Yes
# 14  5129-JLPIS    Male              0      No         No      25          Yes
# 15  3655-SNQYZ  Female              0     Yes        Yes      69          Yes
#
#    MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 8            Yes     Fiber optic             No  ...              Yes
# 12           Yes     Fiber optic             No  ...              Yes
# 13           Yes     Fiber optic             No  ...              Yes
# 14            No     Fiber optic            Yes  ...              Yes
# 15           Yes     Fiber optic            Yes  ...              Yes
#
# ...

# %% [markdown]
# how many customers  paid above 100

# %%
#
paid_above_100.count()
# Out:
# customerID          902
# gender              902
# SeniorCitizen       902
# Partner             902
# Dependents          902
# tenure              902
# PhoneService        902
# MultipleLines       902
# InternetService     902
# OnlineSecurity      902
# OnlineBackup        902
# DeviceProtection    902
# TechSupport         902
# StreamingTV         902
# StreamingMovies     902
# Contract            902
# PaperlessBilling    902
# PaymentMethod       902
# MonthlyCharges      902
# TotalCharges        902
# Churn               902
# dtype: int64

# %% [markdown]
# I’m interested in  customers  who are paying for  monthy and one year contract

# %%
Contract_month_and_1year= telcom[ telcom["Contract"].isin(['Month-to-month','One year'])  ]
Contract_month_and_1year.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %% [markdown]
# I want to work with customer  data for which the Partner status  is known.

# %%
status_no_na = telcom[ telcom["Partner"].notna()]
status_no_na.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %% [markdown]
# # How do I select specific rows and columns from a DataFrame?

# %% [markdown]
# I’m interested in rows 10 till 25 and columns 3 to 5.

# %%
telcom.iloc[10:26, 2:5]
# Out:
#     SeniorCitizen Partner Dependents
# 10              0     Yes        Yes
# 11              0      No         No
# 12              0     Yes         No
# 13              0      No         No
# 14              0      No         No
# 15              0     Yes        Yes
# 16              0      No         No
# 17              0      No        Yes
# 18              0     Yes        Yes
# 19              0      No         No
# 20              1      No         No
# 21              0     Yes         No
# 22              0      No         No
# 23              0     Yes         No
# 24              0     Yes        Yes
# 25              0      No         No

# %%
telcom.iloc[0:3, 3] = "anonymous"
telcom.head(5)
# Out:
#    customerID  gender  SeniorCitizen    Partner Dependents  tenure  \
# 0  7590-VHVEG  Female              0  anonymous         No       1
# 1  5575-GNVDE    Male              0  anonymous         No      34
# 2  3668-QPYBK    Male              0  anonymous         No       2
# 3  7795-CFOCW    Male              0         No         No      45
# 4  9237-HQITU  Female              0         No         No       2
#
#   PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0           No  No phone service             DSL             No  ...
# 1          Yes                No             DSL            Yes  ...
# 2          Yes                No             DSL            Yes  ...
# 3           No  No phone service             DSL            Yes  ...
# 4          Yes                No     Fiber optic             No  ...
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# ...

# %% [markdown]
# # How to create plots in pandas?

# %% [markdown]
# ![title](img/plot.png)

# %% [markdown]
# The .plot.* methods are applicable on both Series and DataFrames
#
# By default, each of the columns is plotted as a different element (line, boxplot,…)
#
# Any plot created by pandas is a Matplotlib object.

# %%
telcom.plot()

# %%
telcom["MonthlyCharges"].plot()

# %%
telcom.tenure.plot.box()

# %% [markdown]
# # How to create new columns derived from existing columns?¶

# %% [markdown]
# ![cols](img/colums.png)

# %% [markdown]
# Create a new column by assigning the output to the DataFrame with a new column name in between the [].
#
# Operations are element-wise, no need to loop over rows.
#
# Use rename with a dictionary or function to rename row labels or column names.

# %% [markdown]
# I want forecast montly sales in the next 10months

# %%
telcom["ForecastMonthly"] =telcom["MonthlyCharges"] * 10
telcom.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... TechSupport  \
# 0  No phone service             DSL             No  ...          No
# 1                No             DSL            Yes  ...          No
# 2                No             DSL            Yes  ...          No
# 3  No phone service             DSL            Yes  ...         Yes
# 4                No     Fiber optic             No  ...          No
#
#   StreamingTV StreamingMovies        Contract PaperlessBilling  \
# ...

# %% [markdown]
# I want to rename the data columns

# %%
telcom_renamed=telcom.rename(
       columns={"ForecastMonthly": "Forecast","Churn":"ChurnedCustomer"})

# %%
telcom_renamed.head(2)
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... TechSupport  \
# 0  No phone service             DSL             No  ...          No
# 1                No             DSL            Yes  ...          No
#
#   StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No              No  Month-to-month              Yes
# 1          No              No        One year               No
#
#       PaymentMethod MonthlyCharges TotalCharges  ChurnedCustomer Forecast
# 0  Electronic check          29.85        29.85               No    298.5
# 1      Mailed check          56.95       1889.5               No    569.5
#
# [2 rows x 22 columns]

# %% [markdown]
# # How to calculate summary statistics?

# %% [markdown]
# ![agg](img/agg.png)

# %% [markdown]
# Aggregation statistics can be calculated on entire columns or rows
#
# groupby provides the power of the split-apply-combine pattern
#
# value_counts is a convenient shortcut to count the number of entries in each category of a variable

# %%
# get dataset # https://github.com/mwaskom/seaborn-data
import seaborn as sns 
titanic= sns.load_dataset('titanic')
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# What is the average age of the titanic passengers?

# %%
titanic["age"].mean()
# Out:
# 29.69911764705882

# %% [markdown]
# What is the median age and ticket fare price of the titanic passengers?

# %%
 titanic[["age", "fare"]].median()
# Out:
# age     28.0000
# fare    14.4542
# dtype: float64

# %%
#The aggregating statistic can be calculated for multiple columns at the same time. 
titanic[["age", "fare"]].describe()
# Out:
#               age        fare
# count  714.000000  891.000000
# mean    29.699118   32.204208
# std     14.526497   49.693429
# min      0.420000    0.000000
# 25%     20.125000    7.910400
# 50%     28.000000   14.454200
# 75%     38.000000   31.000000
# max     80.000000  512.329200

# %%
#Instead of the predefined statistics, 
#specific combinations of aggregating statistics for given columns can be defined using the DataFrame.agg() method:
titanic.agg({'age': ['min', 'max', 'median', 'skew'],
             'fare': ['min', 'max', 'median', 'mean']})
# Out:
#               age        fare
# max     80.000000  512.329200
# mean          NaN   32.204208
# median  28.000000   14.454200
# min      0.420000    0.000000
# skew     0.389108         NaN

# %% [markdown]
# What is the average age for male versus female titanic passengers?

# %%
titanic[["sex", "age"]].groupby("sex").mean()
# Out:
#               age
# sex
# female  27.915709
# male    30.726645

# %% [markdown]
# What is the mean ticket fare price for each of the sex and cabin class combinations?

# %%
titanic.groupby(["sex", "pclass"])["fare"].mean()
# Out:
# sex     pclass
# female  1         106.125798
#         2          21.970121
#         3          16.118810
# male    1          67.226127
#         2          19.741782
#         3          12.661633
# Name: fare, dtype: float64

# %% [markdown]
# What is the number of passengers in each of the cabin classes?

# %%
titanic["pclass"].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: pclass, dtype: int64

# %%
titanic.groupby("pclass")["pclass"].count()
# Out:
# pclass
# 1    216
# 2    184
# 3    491
# Name: pclass, dtype: int64

# %% [markdown]
# # How to reshape the layout of tables?
# Sort table rows¶

# %%
#I want to sort the titanic data according to the age of the passengers.
titanic.sort_values(by="age").head()
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 803         1       3    male  0.42      0      1   8.5167        C   Third
# 755         1       2    male  0.67      1      1  14.5000        S  Second
# 644         1       3  female  0.75      2      1  19.2583        C   Third
# 469         1       3  female  0.75      2      1  19.2583        C   Third
# 78          1       2    male  0.83      0      2  29.0000        S  Second
#
#        who  adult_male deck  embark_town alive  alone
# 803  child       False  NaN    Cherbourg   yes  False
# 755  child       False  NaN  Southampton   yes  False
# 644  child       False  NaN    Cherbourg   yes  False
# 469  child       False  NaN    Cherbourg   yes  False
# 78   child       False  NaN  Southampton   yes  False

# %% [markdown]
# want to sort the titanic data according to the cabin class and age in descending order.

# %%
titanic.sort_values(by=['pclass', 'age'], ascending=False).head()
# Out:
#      survived  pclass     sex   age  sibsp  parch    fare embarked  class  \
# 851         0       3    male  74.0      0      0  7.7750        S  Third
# 116         0       3    male  70.5      0      0  7.7500        Q  Third
# 280         0       3    male  65.0      0      0  7.7500        Q  Third
# 483         1       3  female  63.0      0      0  9.5875        S  Third
# 326         0       3    male  61.0      0      0  6.2375        S  Third
#
#        who  adult_male deck  embark_town alive  alone
# 851    man        True  NaN  Southampton    no   True
# 116    man        True  NaN   Queenstown    no   True
# 280    man        True  NaN   Queenstown    no   True
# 483  woman       False  NaN  Southampton   yes   True
# 326    man        True  NaN  Southampton    no   True
