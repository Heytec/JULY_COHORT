# %%
# Import Standard packages
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# %%time
df=pd.read_csv("onlinedata.csv")
# Out:
# Wall time: 941 ms

# %%
df.head()
# Out:
#    Unnamed: 0 InvoiceNo StockCode                          Description  \
# 0           0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER
# 1           1    536365     71053                  WHITE METAL LANTERN
# 2           2    536365    84406B       CREAM CUPID HEARTS COAT HANGER
# 3           3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE
# 4           4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.
#
#    Quantity     InvoiceDate  UnitPrice  CustomerID         Country  Price
# 0         6  12/1/2010 8:26       2.55     17850.0  United Kingdom  15.30
# 1         6  12/1/2010 8:26       3.39     17850.0  United Kingdom  20.34
# 2         8  12/1/2010 8:26       2.75     17850.0  United Kingdom  22.00
# 3         6  12/1/2010 8:26       3.39     17850.0  United Kingdom  20.34
# 4         6  12/1/2010 8:26       3.39     17850.0  United Kingdom  20.34

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 10 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Unnamed: 0   541909 non-null  int64
#  1   InvoiceNo    541909 non-null  object
#  2   StockCode    541909 non-null  object
#  3   Description  540455 non-null  object
#  4   Quantity     541909 non-null  int64
#  5   InvoiceDate  541909 non-null  object
#  6   UnitPrice    541909 non-null  float64
#  7   CustomerID   406829 non-null  float64
#  8   Country      541909 non-null  object
#  9   Price        541909 non-null  float64
# dtypes: float64(3), int64(2), object(5)
# memory usage: 41.3+ MB

# %%
df.shape
# Out:
# (541909, 10)

# %%
df.describe()
# Out:
#          Unnamed: 0       Quantity      UnitPrice     CustomerID  \
# count  541909.00000  541909.000000  541909.000000  406829.000000
# mean   270954.00000       9.552250       4.611114   15287.690570
# std    156435.79785     218.081158      96.759853    1713.600303
# min         0.00000  -80995.000000  -11062.060000   12346.000000
# 25%    135477.00000       1.000000       1.250000   13953.000000
# 50%    270954.00000       3.000000       2.080000   15152.000000
# 75%    406431.00000      10.000000       4.130000   16791.000000
# max    541908.00000   80995.000000   38970.000000   18287.000000
#
#                Price
# count  541909.000000
# mean       17.987795
# std       378.810824
# min   -168469.600000
# 25%         3.400000
# 50%         9.750000
# 75%        17.400000
# max    168469.600000

# %% [markdown]
# # Monthly Revenue Overview

# %%
df.head()
# Out:
#    Unnamed: 0 InvoiceNo StockCode                          Description  \
# 0           0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER
# 1           1    536365     71053                  WHITE METAL LANTERN
# 2           2    536365    84406B       CREAM CUPID HEARTS COAT HANGER
# 3           3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE
# 4           4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.
#
#    Quantity     InvoiceDate  UnitPrice  CustomerID         Country  Price
# 0         6  12/1/2010 8:26       2.55     17850.0  United Kingdom  15.30
# 1         6  12/1/2010 8:26       3.39     17850.0  United Kingdom  20.34
# 2         8  12/1/2010 8:26       2.75     17850.0  United Kingdom  22.00
# 3         6  12/1/2010 8:26       3.39     17850.0  United Kingdom  20.34
# 4         6  12/1/2010 8:26       3.39     17850.0  United Kingdom  20.34

# %%
df["InvoiceDate"]=pd.to_datetime(df["InvoiceDate"]).dt.date
df["InvoiceMonth"]=pd.DatetimeIndex(df["InvoiceDate"]).month
df["InvoiceYear"]=pd.DatetimeIndex(df["InvoiceDate"]).year

# %%
# %%time 
df["InvoiceMonth"]=pd.DatetimeIndex(df["InvoiceDate"]).month

# %%
df.head()
# Out:
#    Unnamed: 0 InvoiceNo StockCode                          Description  \
# 0           0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER
# 1           1    536365     71053                  WHITE METAL LANTERN
# 2           2    536365    84406B       CREAM CUPID HEARTS COAT HANGER
# 3           3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE
# 4           4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.
#
#    Quantity     InvoiceDate  UnitPrice  CustomerID         Country  Price  \
# 0         6  12/1/2010 8:26       2.55     17850.0  United Kingdom  15.30
# 1         6  12/1/2010 8:26       3.39     17850.0  United Kingdom  20.34
# 2         8  12/1/2010 8:26       2.75     17850.0  United Kingdom  22.00
# 3         6  12/1/2010 8:26       3.39     17850.0  United Kingdom  20.34
# 4         6  12/1/2010 8:26       3.39     17850.0  United Kingdom  20.34
#
#    InvoiceMonth
# 0            12
# 1            12
# 2            12
# 3            12
# 4            12

# %%
# %%time 
df["InvoiceDate"]=pd.to_datetime(df["InvoiceDate"]).dt.date
df["InvoiceYear"]=pd.DatetimeIndex(df["InvoiceDate"]).year
# Out:
# Wall time: 2.78 s

# %%
df.head()
# Out:
#    Unnamed: 0 InvoiceNo StockCode                          Description  \
# 0           0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER
# 1           1    536365     71053                  WHITE METAL LANTERN
# 2           2    536365    84406B       CREAM CUPID HEARTS COAT HANGER
# 3           3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE
# 4           4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.
#
#    Quantity InvoiceDate  UnitPrice  CustomerID         Country  Price  \
# 0         6  2010-12-01       2.55     17850.0  United Kingdom  15.30
# 1         6  2010-12-01       3.39     17850.0  United Kingdom  20.34
# 2         8  2010-12-01       2.75     17850.0  United Kingdom  22.00
# 3         6  2010-12-01       3.39     17850.0  United Kingdom  20.34
# 4         6  2010-12-01       3.39     17850.0  United Kingdom  20.34
#
#    InvoiceMonth  InvoiceYear
# 0            12         2010
# 1            12         2010
# 2            12         2010
# 3            12         2010
# 4            12         2010

# %%
df["Revenue"]=df["UnitPrice"]*df["Quantity"]

# %%
df.head()
# Out:
#    Unnamed: 0 InvoiceNo StockCode                          Description  \
# 0           0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER
# 1           1    536365     71053                  WHITE METAL LANTERN
# 2           2    536365    84406B       CREAM CUPID HEARTS COAT HANGER
# 3           3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE
# 4           4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.
#
#    Quantity InvoiceDate  UnitPrice  CustomerID         Country  Price  \
# 0         6  2010-12-01       2.55     17850.0  United Kingdom  15.30
# 1         6  2010-12-01       3.39     17850.0  United Kingdom  20.34
# 2         8  2010-12-01       2.75     17850.0  United Kingdom  22.00
# 3         6  2010-12-01       3.39     17850.0  United Kingdom  20.34
# 4         6  2010-12-01       3.39     17850.0  United Kingdom  20.34
#
#    InvoiceMonth  InvoiceYear  Revenue
# 0            12         2010    15.30
# 1            12         2010    20.34
# 2            12         2010    22.00
# 3            12         2010    20.34
# 4            12         2010    20.34

# %%
# Look for missing values
df.isnull().sum()
# Out:
# Unnamed: 0           0
# InvoiceNo            0
# StockCode            0
# Description       1454
# Quantity             0
# InvoiceDate          0
# UnitPrice            0
# CustomerID      135080
# Country              0
# Price                0
# InvoiceMonth         0
# InvoiceYear          0
# Revenue              0
# dtype: int64

# %%
df.head()
# Out:
#    Unnamed: 0 InvoiceNo StockCode                          Description  \
# 0           0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER
# 1           1    536365     71053                  WHITE METAL LANTERN
# 2           2    536365    84406B       CREAM CUPID HEARTS COAT HANGER
# 3           3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE
# 4           4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.
#
#    Quantity InvoiceDate  UnitPrice  CustomerID         Country  Price  \
# 0         6  2010-12-01       2.55     17850.0  United Kingdom  15.30
# 1         6  2010-12-01       3.39     17850.0  United Kingdom  20.34
# 2         8  2010-12-01       2.75     17850.0  United Kingdom  22.00
# 3         6  2010-12-01       3.39     17850.0  United Kingdom  20.34
# 4         6  2010-12-01       3.39     17850.0  United Kingdom  20.34
#
#    InvoiceMonth  InvoiceYear  Revenue
# 0            12         2010    15.30
# 1            12         2010    20.34
# 2            12         2010    22.00
# 3            12         2010    20.34
# 4            12         2010    20.34

# %%
df_revenue=df.groupby(["InvoiceMonth", "InvoiceYear"])["Revenue"].sum().reset_index()
df_revenue
# Out:
#     InvoiceMonth  InvoiceYear      Revenue
# 0              1         2011   560000.260
# 1              2         2011   498062.650
# 2              3         2011   683267.080
# 3              4         2011   493207.121
# 4              5         2011   723333.510
# 5              6         2011   691123.120
# 6              7         2011   681300.111
# 7              8         2011   682680.510
# 8              9         2011  1019687.622
# 9             10         2011  1070704.670
# 10            11         2011  1461756.250
# 11            12         2010   748957.020
# 12            12         2011   433668.010

# %%
plt.figure(figsize=(15,10))
sns.barplot(x="InvoiceMonth", y="Revenue", hue="InvoiceYear", data=df_revenue)
plt.title("Monthly Revenue")
plt.xlabel("Month")
plt.ylabel("Revenue")
# Out:
# Text(0, 0.5, 'Revenue')

# %%
plt.figure()
sns.relplot(x="InvoiceMonth", y="Revenue", hue="InvoiceYear", kind="line", data=df_revenue, height=10, aspect=15/10)
plt.title("Monthly Revenue")
plt.xlabel("Month")
plt.ylabel("Revenue")
# Out:
# Text(27.39631076388889, 0.5, 'Revenue')

# %%
# Look at the December 2011 data
df_december_2011=df.query("InvoiceMonth==12 and InvoiceYear==2011")
df_december_2011.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 25525 entries, 516384 to 541908
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    25525 non-null  int64
#  1   InvoiceNo     25525 non-null  object
#  2   StockCode     25525 non-null  object
#  3   Description   25510 non-null  object
#  4   Quantity      25525 non-null  int64
#  5   InvoiceDate   25525 non-null  object
#  6   UnitPrice     25525 non-null  float64
#  7   CustomerID    17661 non-null  float64
#  8   Country       25525 non-null  object
#  9   Price         25525 non-null  float64
#  10  InvoiceMonth  25525 non-null  int64
#  11  InvoiceYear   25525 non-null  int64
#  12  Revenue       25525 non-null  float64
# dtypes: float64(4), int64(4), object(5)
# memory usage: 2.7+ MB

# %%
# Monthly Items Sold Overview
df_quantity=df.groupby(["InvoiceMonth", "InvoiceYear"])["Quantity"].sum().reset_index()
plt.figure(figsize=(15,10))
sns.barplot(x="InvoiceMonth", y="Quantity", data=df_quantity)
plt.title("Monthly Items Sold")
plt.xlabel("Month")
plt.ylabel("Items Sold")

# %%
df.head()
# Out:
#    Unnamed: 0 InvoiceNo StockCode                          Description  \
# 0           0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER
# 1           1    536365     71053                  WHITE METAL LANTERN
# 2           2    536365    84406B       CREAM CUPID HEARTS COAT HANGER
# 3           3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE
# 4           4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.
#
#    Quantity InvoiceDate  UnitPrice  CustomerID         Country  Price  \
# 0         6  2010-12-01       2.55     17850.0  United Kingdom  15.30
# 1         6  2010-12-01       3.39     17850.0  United Kingdom  20.34
# 2         8  2010-12-01       2.75     17850.0  United Kingdom  22.00
# 3         6  2010-12-01       3.39     17850.0  United Kingdom  20.34
# 4         6  2010-12-01       3.39     17850.0  United Kingdom  20.34
#
#    InvoiceMonth  InvoiceYear  Revenue
# 0            12         2010    15.30
# 1            12         2010    20.34
# 2            12         2010    22.00
# 3            12         2010    20.34
# 4            12         2010    20.34

# %%
# Monthly Items Sold Overview
df_quantity=df.groupby(["InvoiceMonth", "InvoiceYear"])["Quantity"].sum().reset_index()
plt.figure(figsize=(15,10))
sns.barplot(x="InvoiceMonth", y="Quantity", data=df_quantity)
plt.title("Monthly Items Sold")
plt.xlabel("Month")
plt.ylabel("Items Sold")
# Out:
# Text(0, 0.5, 'Items Sold')

# %%
df.head()
# Out:
#    Unnamed: 0 InvoiceNo StockCode                          Description  \
# 0           0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER
# 1           1    536365     71053                  WHITE METAL LANTERN
# 2           2    536365    84406B       CREAM CUPID HEARTS COAT HANGER
# 3           3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE
# 4           4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.
#
#    Quantity InvoiceDate  UnitPrice  CustomerID         Country  Price  \
# 0         6  2010-12-01       2.55     17850.0  United Kingdom  15.30
# 1         6  2010-12-01       3.39     17850.0  United Kingdom  20.34
# 2         8  2010-12-01       2.75     17850.0  United Kingdom  22.00
# 3         6  2010-12-01       3.39     17850.0  United Kingdom  20.34
# 4         6  2010-12-01       3.39     17850.0  United Kingdom  20.34
#
#    InvoiceMonth  InvoiceYear  Revenue
# 0            12         2010    15.30
# 1            12         2010    20.34
# 2            12         2010    22.00
# 3            12         2010    20.34
# 4            12         2010    20.34

# %%
df_active=df.groupby(["InvoiceMonth", "InvoiceYear"])["CustomerID"].nunique().reset_index() #.nunique().reset_index()
df_active
# Out:
#     InvoiceMonth  InvoiceYear  CustomerID
# 0              1         2011         783
# 1              2         2011         798
# 2              3         2011        1020
# 3              4         2011         899
# 4              5         2011        1079
# 5              6         2011        1051
# 6              7         2011         993
# 7              8         2011         980
# 8              9         2011        1302
# 9             10         2011        1425
# 10            11         2011        1711
# 11            12         2010         948
# 12            12         2011         686

# %%
plt.figure(figsize=(15,10))
sns.barplot(x="InvoiceMonth", y="CustomerID", hue="InvoiceYear", data=df_active)
plt.title("Monthly Active Users")
plt.xlabel("Month")
plt.ylabel("Active Users")
# Out:
# Text(0, 0.5, 'Active Users')

# %%
# Average Revenue per Month
df_revenue_avg=df.groupby(["InvoiceMonth", "InvoiceYear"])["Revenue"].mean().reset_index()
plt.figure(figsize=(15,10))
sns.barplot(x="InvoiceMonth", y="Revenue", data=df_revenue)
plt.title("Monthly Average Revenue ")
plt.xlabel("Month")
plt.ylabel("Revenue")
# Out:
# Text(0, 0.5, 'Revenue')

# %% [markdown]
# # New vs Existing Users

# %%
df.head()
# Out:
#    Unnamed: 0 InvoiceNo StockCode                          Description  \
# 0           0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER
# 1           1    536365     71053                  WHITE METAL LANTERN
# 2           2    536365    84406B       CREAM CUPID HEARTS COAT HANGER
# 3           3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE
# 4           4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.
#
#    Quantity InvoiceDate  UnitPrice  CustomerID         Country  Price  \
# 0         6  2010-12-01       2.55     17850.0  United Kingdom  15.30
# 1         6  2010-12-01       3.39     17850.0  United Kingdom  20.34
# 2         8  2010-12-01       2.75     17850.0  United Kingdom  22.00
# 3         6  2010-12-01       3.39     17850.0  United Kingdom  20.34
# 4         6  2010-12-01       3.39     17850.0  United Kingdom  20.34
#
#    InvoiceMonth  InvoiceYear  Revenue
# 0            12         2010    15.30
# 1            12         2010    20.34
# 2            12         2010    22.00
# 3            12         2010    20.34
# 4            12         2010    20.34

# %%
#option1
df_first_purchase=df.groupby(["CustomerID"])["InvoiceDate"].min().reset_index()
df_first_purchase.columns=["CustomerID", "FirstPurchaseDate"]
df=pd.merge(df, df_first_purchase, on="CustomerID")
df.head(1)
#option2
#df[ "FirstPurchaseDate"]=df.groupby(["CustomerID"])["InvoiceDate"].min().reset_index()
# Out:
#    Unnamed: 0 InvoiceNo StockCode                         Description  \
# 0           0    536365    85123A  WHITE HANGING HEART T-LIGHT HOLDER
#
#    Quantity InvoiceDate  UnitPrice  CustomerID         Country  Price  \
# 0         6  2010-12-01       2.55     17850.0  United Kingdom   15.3
#
#    InvoiceMonth  InvoiceYear  Revenue FirstPurchaseDate_x FirstPurchaseDate_y  \
# 0            12         2010     15.3          2010-12-01          2010-12-01
#
#   UserType FirstPurchaseDate
# 0      New        2010-12-01

# %%
df["UserType"]="New"

# %%
df.head(1)
# Out:
#    Unnamed: 0 InvoiceNo StockCode                         Description  \
# 0           0    536365    85123A  WHITE HANGING HEART T-LIGHT HOLDER
#
#    Quantity InvoiceDate  UnitPrice  CustomerID         Country  Price  \
# 0         6  2010-12-01       2.55     17850.0  United Kingdom   15.3
#
#    InvoiceMonth  InvoiceYear  Revenue FirstPurchaseDate_x FirstPurchaseDate_y  \
# 0            12         2010     15.3          2010-12-01          2010-12-01
#
#   UserType FirstPurchaseDate
# 0      New        2010-12-01

# %%
df.loc[df["InvoiceDate"]>df["FirstPurchaseDate"], "UserType"]="Existing"

# %%
df.UserType.value_counts()
# Out:
# Existing    301296
# New         105533
# Name: UserType, dtype: int64

# %%
df_new_revenue=df.groupby(["InvoiceMonth", "InvoiceYear", "UserType"])["Revenue"].sum().reset_index()
plt.figure()
sns.relplot(x="InvoiceMonth", y="Revenue", hue="UserType", data=df_new_revenue, kind="line", height=12, aspect=18/10)
plt.title("New vs Existing Customer Revenue Overview")
plt.xlabel("Month")
plt.ylabel("Revenue")
# Out:
# Text(24.844047037760433, 0.5, 'Revenue')

# %%
df_new_revenue=df.groupby(["InvoiceMonth", "InvoiceYear", "UserType"])["Revenue"].sum().reset_index()
plt.figure()
sns.catplot(x="InvoiceMonth", y="Revenue", hue="UserType", data=df_new_revenue, kind="bar", height=12, aspect=18/10)
plt.title("New vs Existing Customer Revenue Overview")
plt.xlabel("Month")
plt.ylabel("Revenue")
# Out:
# Text(24.485944733796302, 0.5, 'Revenue')
