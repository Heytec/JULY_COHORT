# %% [markdown]
# Matplotlib is a python  package used for 2d graphics

# %%
Box plot
Histogram
scatter plot
pie plot 
Area plot

# %% [markdown]
# # Simple graph

# %%
from  matplotlib import pyplot as plt 

# X,y data 
x=[1,2,3]
y=[4,5,6]

#plot canvas
plt.plot(x,y)

#show graph 
plt.show

# %% [markdown]
# # ADD title ,lables and ploting variables

# %%
from  matplotlib import pyplot as plt 

# X,y data 
x=[1,2,3]
y=[4,5,6]

#plot canvas
plt.plot(x,y)


#title 
plt.title('Simple graph ')
plt.ylabel('Y axis ')
plt.xlabel('x axis')
#show graph 
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # Adding style to graph

# %%
from  matplotlib import pyplot as plt 
from matplotlib import style 

style.use('ggplot')

# X,y data 
x=[5,8,10]
y=[12,16,6]

# X2,y2 data 
x2=[6,9,12]
y2=[6,15,7]

#plot canvas
plt.plot(x,y,'g',label='one',linewidth=7)
plt.plot(x2,y2,'c',label='two',linewidth=7)

plt.legend()
#title 
plt.title('Simple graph ')
plt.ylabel('Y axis ')
plt.xlabel('x axis')


plt.grid(True,color='k')
#show graph 
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
